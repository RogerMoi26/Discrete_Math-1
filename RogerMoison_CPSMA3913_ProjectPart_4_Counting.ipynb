# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerMoi26/Discrete_Math-1/blob/master/RogerMoison_CPSMA3913_ProjectPart_4_Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Counting
#
# ### Roger Moison and 282541

# %% [markdown]
# Okay this week is a fun one... so lets jump in shall we.
# last week i used my daughter as the example but i dont think that will work for this one. but imma do it anyway..

# %% [markdown]
# There are *7* possible gifts my daughter will recieve for her birthday and *10* presents to chose from

# %%
possibleChoices = ['Shirts','Stuffed Animal','Shoes','Money','Books','Pants','Socks']

# %% [markdown]
# ## 1 (a)

# %% [markdown]
# $$ 7*7*7\dots *7 = 7^{10} $$

# %% [markdown]
# Now i did not wrap the gifts so i dont know what is in which gift.

# %%
7**10
# Out:
# 282475249

# %% [markdown]
# #(b)

# %% [markdown]
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$

# %%
import math

math.factorial(16)/(math.factorial(10)*math.factorial(6))
# Out:
# 8008.0

# %% [markdown]
# ## (c)

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(possibleChoices,10)))
# Out:
# [('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Stuffed Animal'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shoes'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Money'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Books'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Pants'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Socks'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Stuffed Animal', 'Stuffed Animal'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'Stuffed Animal', 'Shoes'), ('Shirts', 'Shirts', 'Shirts', 'Shirts', 'Shirts', 'S
# ...

# %%
len(list(combinations_with_replacement(possibleChoices,10)))
# Out:
# 8008

# %%
print(math.factorial(7))
# Out:
# 5040

# %% [markdown]
# and out of those 7 gift choices I have 5040 possibilities.

# %% [markdown]
# When order matters

# %%
from itertools import permutations
print(list(permutations(possibleChoices,7)))
# Out:
# [('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Books', 'Pants', 'Socks'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Books', 'Socks', 'Pants'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Pants', 'Books', 'Socks'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Pants', 'Socks', 'Books'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Socks', 'Books', 'Pants'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Socks', 'Pants', 'Books'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Money', 'Pants', 'Socks'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Money', 'Socks', 'Pants'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Pants', 'Money', 'Socks'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Pants', 'Socks', 'Money'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Socks', 'Money', 'Pants'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Books', 'Socks', 'Pants', 'Money'), ('Shirts', 'Stuffed Animal', 'Shoes', 'Pants', 'Money', 'Books', 'Socks'), ('Shirts', 'Stuffed An
# ...

# %% [markdown]
# When it does not

# %%
math.factorial(7)/(math.factorial(0)*math.factorial(7))
# Out:
# 1.0

# %%
from itertools import combinations
print(list(combinations(possibleChoices,7)))
# Out:
# [('Shirts', 'Stuffed Animal', 'Shoes', 'Money', 'Books', 'Pants', 'Socks')]

# %% [markdown]
# # (d)

# %% [markdown]
# What is the coefficent of the 5th order of (x-3)^9?
# So lets take 9C5
#
# I hated this so the answer would be 126
