# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerMoi26/Discrete_Math-1/blob/master/Copy_of_RogerMoison_CPSMA3913_ProjectPart_5_Structuers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 5: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Structures
#
# ### Roger Moison and 282541

# %% [markdown]
# Alright so this weeks project isnt too bad and looks pretty fun.
#
# The Tree I will be doing will be a family tree which I might go crazy with so lets see what I can do shall we

# %% [markdown]
# # (a)

# %% [markdown]
# I was going to do somthing huge and super complex but I didnt like the numbers so I have made it simpler

# %% [markdown]
# # (b)

# %% [markdown]
# Here the package is vizualized.

# %%
import graphviz
moison = graphviz.Digraph('MoisonFamilyTree')

moison.edge('Roger','Melanie',label = 'Married')
moison.edge('Dad','Mom',label = 'Married')
moison.edge('Codey','Shirin',label = 'Married')
moison.edge('Melanie','Leyah','Daughter')
moison.edge('Melanie','Shirin','Best-Friends')
moison.edge('Shirin','Alice','Daughter')
moison.edge('Mom','Roger','Son')
moison.edge('Mom','James','Son')
moison.edge('Mom','Codey','Son')

moison

# %% [markdown]
# # (c)

# %% [markdown]
# Alright so lets talk about the path of this thing I wanted to make it super complicated at first but then realized I was making more work for myself thus we now have what you see. The path is as follows My father (Dad) flows down to my mother (Mom), which then flows down to myself and my brothers. It then flows from me to my wife and daughter. It does the same for Codey my youngest brother and his wife . My Melanie and Shirin are best friend and when shirin got engaged to codey they introduced me and melaine . My wife and i had our kid first then codey and shirin.

# %% [markdown]
# #(d)

# %%
sum = 0 

for i in range(9):
  sum = sum + 2**i
  print(sum)
# Out:
# 1
# 3
# 7
# 15
# 31
# 63
# 127
# 255
# 511

# %% [markdown]
# I think i did that correct.

# %% [markdown]
# # (e)

# %% [markdown]
# There is no cycle in my structure as it is a tree as it currently end with James ,Leyah and Alice. My tree would be considered a Rooted tree with my father as the root.

# %% [markdown]
# I want to say that I covered everything asked for this week if I havent Im sure will let me know. Stay safe warm and healthy out there I am unfortunately sick while doing this lol, but the work most go on.
