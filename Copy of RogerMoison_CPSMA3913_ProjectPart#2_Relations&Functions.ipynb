# %% [markdown]
# # Project Part # 2 : CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Ralations and Functions
#
# ### Roger Moison / 282541

# %% [markdown]
# ## Defining a function

# %% [markdown]
# So lets keep this simple shall we the function I will define is the Inverse function super simple right? Well lets jump into the code.
#
# $$
# f(x) = \frac{2x-1}{x-3}
# $$

# %% [markdown]
# Wow that actually pretty cool if you do it correctly!
# Back on track I will def inverse and i actully didnt need to import im sure i would have if i had used the example but this is the only simple function i could think of.

# %%
def inverse(x):
  return 2*x-1/x-3

# %%
inverse(8)
# Out:
# 12.875

# %% [markdown]
# Awesome it worked!!

# %% [markdown]
# # Graphing the function

# %% [markdown]
# Now I will be graphing. The window I will chose form $[-1,1]$ because no reason in particular just the first number to pop in my head.
# The

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-1,1,.2)
plt.plot(x,inverse(x))

# %% [markdown]
# Now i have played around with and manipulated the numbers a bit and I am 100% sure im missing somthing because im sure the graph needs to be curvy not pointed.

# %% [markdown]
# ## Define a Dictionary

# %% [markdown]
# Defining my dictionary between two sets ImmediateFamily and Family

# %%
BigFamily = 'Roger','Melanie','Leyah','Codey','James','Shirin','Alice','Peaches'
Family = 'Myself','Leah','Codey','James','Alice','Wicket'

dictionary = dict({b:f for b,f in zip(BigFamily,Family)})

# %%
dictionary
# Out:
# {'Roger': 'Myself',
#  'Melanie': 'Leah',
#  'Leyah': 'Codey',
#  'Codey': 'James',
#  'James': 'Alice',
#  'Shirin': 'Wicket'}

# %%
MyDictionary = dict({'Myself':'Roger','Peaches':'Wicket','Wicket':'Peaches'})

# %%
newlist = [MyDictionary.get(x,x) for x in BigFamily]

# %%
newlist
# Out:
# ['Roger', 'Melanie', 'Leyah', 'Codey', 'James', 'Shirin', 'Alice', 'Wicket']

# %% [markdown]
# # Findings and conclusions

# %% [markdown]
# The use of the Latex code was cool and to see that if done correctly a function can be made to appear correct and function.
# The graphing was also interesting how ever I highly doubt i got it to work as it should so I will definatly need to buckle down and try and figure out where i went wrong. Lastly the dictionary was fairly simple and i used my family for it so that was fun.
# Please in the disscusion feel free to speak your mind on my code feel free to tell me how i can get photos on here cause this looks so boring and how i might improve my code/ get the graphing to work properly I look foward to this peer review and see everyones projects and what functions yall chose.
